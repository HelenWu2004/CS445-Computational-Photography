# %% [markdown]
# # Programming Project #1: Hybrid Images

# %% [markdown]
# ## CS445: Computational Photography

# %% [markdown]
# ### Part I: Hybrid Images

# %%
# # Optional, if using Google Colab w/ Drive
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
import cv2

import numpy as np
from matplotlib.colors import LogNorm
from scipy import signal

# modify to where you store your project data including utils.py
datadir = "/Users/helenwu/Desktop/hybrid_4/" 

utilfn = datadir + "utils.py"
# !cp "$utilfn" .
import utils
# Out:
# cp: ./utils.py and /Users/helenwu/Desktop/hybrid_4/utils.py are identical (not copied).

# %%
# switch from notebook to inline if using colab or otherwise cannot use interactive display)
# %matplotlib notebook  
# %matplotlib ipympl
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
im1_file = datadir + 'nutmeg.jpg'
im2_file = datadir + 'DerekPicture.jpg'

im1 = np.float32(cv2.imread(im1_file, cv2.IMREAD_GRAYSCALE) / 255.0)
im2 = np.float32(cv2.imread(im2_file, cv2.IMREAD_GRAYSCALE) / 255.0)

# %%
# ! pip install ipympl

# %%
pts_im1 = utils.prompt_eye_selection(im1)
pts_im1 = np.array([[607, 290], [748, 370]]) # uncomment if entering [x, y] pts manually
plt.plot(pts_im1[:,0], pts_im1[:,1], 'r-+')
# Out:
# <div id='89167823-40f4-416c-887f-246cc6115560'></div>

# %%
pts_im2 = utils.prompt_eye_selection(im2)
pts_im2 = np.array([[299,343], [439,331]]) # uncomment if entering [x, y] pts manually
plt.plot(pts_im2[:,0], pts_im2[:,1], 'r-+')
# Out:
# <div id='f897f554-4998-4648-80a8-ca3d900fb32c'></div>

# %%
im1, im2 = utils.align_images(im1_file, im2_file,pts_im1,pts_im2,save_images=False)

# %%
# convert to grayscale
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) / 255.0
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY) / 255.0

# %%
#Images sanity check
fig, axes = plt.subplots(1, 2)
axes[0].imshow(im1,cmap='gray')
axes[0].set_title('Image 1'), axes[0].set_xticks([]), axes[0].set_yticks([])
axes[1].imshow(im2,cmap='gray')
axes[1].set_title('Image 2'), axes[1].set_xticks([]), axes[1].set_yticks([]);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def hybridImage(im1, im2, sigma_low, sigma_high):
    '''
    Inputs:
        im1:    RGB (height x width x 3) or a grayscale (height x width) image
                as a numpy array.
        im2:    RGB (height x width x 3) or a grayscale (height x width) image
                as a numpy array.
        sigma_low: standard deviation for the low-pass filter
        sigma_high: standard deviation for the high-pass filter
        
    Output:
        Return the combination of both images, one filtered with a low-pass filter
        and the other with a high-pass filter.
    '''  

    # your code goes here  
    kernel_low = utils.gaussian_kernel(sigma_low, kernel_half_size=int(3*sigma_low))
    kernel_high = utils.gaussian_kernel(sigma_high, kernel_half_size=int(3*sigma_high))
    
    # Apply low-pass filter to the first image
    low_pass_im1 = cv2.filter2D(im1, -1, kernel_low)
    
    # Apply high-pass filter to the second image
    low_pass_im2 = cv2.filter2D(im2, -1, kernel_high)
    high_pass_im2 = im2 - low_pass_im2  # Subtract low frequencies to get high-pass
    hybrid_image = low_pass_im1 + high_pass_im2
    
    return hybrid_image

# %%
sigma_low = 20 # choose parameters that work for your images
sigma_high = 20

im_hybrid = hybridImage(im2, im1, sigma_low, sigma_high)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 4
#       1 sigma_low = 20 # choose parameters that work for your images
#       2 sigma_high = 20
# ----> 4 im_hybrid = hybridImage(im2, im1, sigma_low, sigma_high)
#
# Cell In[31], line 17, in hybridImage(im1, im2, sigma_low, sigma_high)
#       2 '''
#       3 Inputs:
#       4     im1:    RGB (height x width x 3) or a grayscale (height x width) image
#    (...)
#      13     and the other with a high-pass filter.
#      14 '''
#      16 # your code goes here
# ---> 17 kernel_low = utils.gaussian_kernel(sigma_low, kernel_half_size=int(3*sigma_low))
#      18 kernel_high = utils.gaussian_kernel(sigma_high, kernel_half_size=int(3*sigma_high))
#      20 # Apply low-pass filter to the first image
#
# File ~/Desktop/hybrid_4/utils.py:236, in gaussian_kernel(sigma, kernel_half_size)
#     227 '''
#     228 Inputs:
#     229     sigma = standard deviation for the gaussian kernel
#    (...)
#     233     Returns a 2D Gaussian kernel matrix
#     234 '''
#     235 window_size = kernel_half_size*2+1
# --> 236 gaussian_kernel_1d = signal.gaussian(window_size, std=sigma).reshape(window_size, 1)
#     237 gaussian_kernel_2d = np.outer(gaussian_kernel_1d, gaussian_kernel_1d)
#     238 gaussian_kernel_2d /= np.sum(gaussian_kernel_2d) # make sure it sums to one
#
# AttributeError: module 'scipy.signal' has no attribute 'gaussian'

# %%
# Optional: Select top left corner and bottom right corner to crop image
# the function returns dictionary of 
# {
#   'cropped_image': np.ndarray of shape H x W
#   'crop_bound': np.ndarray of shape 2x2
# }
cropped_object = utils.interactive_crop(im_hybrid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       1 # Optional: Select top left corner and bottom right corner to crop image
#       2 # the function returns dictionary of
#       3 # {
#       4 #   'cropped_image': np.ndarray of shape H x W
#       5 #   'crop_bound': np.ndarray of shape 2x2
#       6 # }
# ----> 7 cropped_object = utils.interactive_crop(im_hybrid)
#
# NameError: name 'im_hybrid' is not defined

# %% [markdown]
# ### Part II: Image Enhancement

# %% [markdown]
# ##### Two out of three types of image enhancement are required.  Choose a good image to showcase each type and implement a method.  This code doesn't rely on the hybrid image part.

# %% [markdown]
# #### Contrast enhancement

# %% [markdown]
# #### Color enhancement

# %% [markdown]
# #### Color shift
